# %%
import pandas as pd 

df = pd.read_csv("/mnt/d/Escritorio/pruebas-codes/udemy/sueldosporcarrera2.csv")

# %%
df = df.dropna()

# %%
subgrupo = ["Carrera", "Percentil 10 con Experiencia", "Percentil 90 con Experiencia"]
df2 = df[subgrupo]

# %%
ordenado = df2.sort_values(by = "Percentil 10 con Experiencia", ascending = True)

# %%
print("Las 10 carreras con los percentiles 10 más bajos son:")
print(ordenado.head(10))
# Out:
# Las 10 carreras con los percentiles 10 más bajos son:
#               Carrera  Percentil 10 con Experiencia  \
# 10             Musica                       29503.5
# 23  Historia del Arte                       31824.0
# 32          Educacion                       32376.5
# 4            Religion                       32818.5
# 1          Sociologia                       33923.5
# 30            Espanol                       34255.0
# 7          Psicologia                       34918.0
# 13  Justicia Criminal                       35581.0
# 14             Ingles                       36907.0
# 46       Antropologia                       37349.0
#
#     Percentil 90 con Experiencia
# 10                      148070.0
# 23                      138125.0
# 32                      112710.0
# 4                       106522.0
# 1                       130390.0
# 30                      106522.0
# 7                       140335.0
# 13                      118235.0
# ...

# %%
mayores = df2[df2["Percentil 90 con Experiencia"] > 150000]

# %%
print("Las carreras con percentil 90 mayor a $150,000 son:")
print(mayores)
# Out:
# Las carreras con percentil 90 mayor a $150,000 son:
#                                Carrera  Percentil 10 con Experiencia  \
# 2   Sistemas de Informacion de Gestion                       50056.5
# 5           Relaciones Internacionales                       42211.0
# 6                              Quimica                       50056.5
# 8                           Periodismo                       42432.0
# 11                         Matematicas                       49946.0
# 12                           Marketing                       46520.5
# 15                  Ingenieria Quimica                       79449.5
# 16                 Ingenieria Mecanica                       70388.5
# 17              Ingenieria Informatica                       73040.5
# 18               Ingenieria Industrial                       63095.5
# 20                    Ingenieria Civil                       70057.0
# 21             Ingenieria Aeroespacial                       71051.5
# ...

# %%
print("¿Cuál es la Carrera con el Percentil 10 más bajo de Sueldo para Profesionales con Experiencia?")
print(ordenado.head(1))
# Out:
# ¿Cuál es la Carrera con el Percentil 10 más bajo de Sueldo para Profesionales con Experiencia?
#    Carrera  Percentil 10 con Experiencia  Percentil 90 con Experiencia
# 10  Musica                       29503.5                      148070.0

# %%
print("Comparta las Carreras con Percentil 90 de Sueldo superior a $150,000 anuales.")
print(mayores)
# Out:
# Comparta las Carreras con Percentil 90 de Sueldo superior a $150,000 anuales.
#                                Carrera  Percentil 10 con Experiencia  \
# 2   Sistemas de Informacion de Gestion                       50056.5
# 5           Relaciones Internacionales                       42211.0
# 6                              Quimica                       50056.5
# 8                           Periodismo                       42432.0
# 11                         Matematicas                       49946.0
# 12                           Marketing                       46520.5
# 15                  Ingenieria Quimica                       79449.5
# 16                 Ingenieria Mecanica                       70388.5
# 17              Ingenieria Informatica                       73040.5
# 18               Ingenieria Industrial                       63095.5
# 20                    Ingenieria Civil                       70057.0
# ...
